# %% [markdown]
# Scatter plot

# %%
import matplotlib.pyplot as plt
# create a figure and axis
fig, ax = plt.subplots()

x = [2,4,6,6,9,2,7,2,6,1,8,4,5,9,1,2,3,7]
y = [7,8,2,4,6,4,9,5,9,3,6,7,2,4,6,7,1,9]

ax.scatter(x,y)

# %%
import pandas as pd;
iris = pd.read_csv('D:/Msc/FDS/Data/Iris.csv',index_col=0)
print(iris.head())
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
# create a figure and axis 
fig, ax = plt.subplots()

# scatter the SepalLength against ScatterWidth
ax.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'])
# Set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('SepalWidthCm')
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
x=range(1,6)
y=np.random.randint(1,20,5)
plt.plot(x,y)

plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x25c757a7280>,
#   <matplotlib.axis.YTick at 0x25c757a4a30>,
#   <matplotlib.axis.YTick at 0x25c757a1d00>,
#   <matplotlib.axis.YTick at 0x25c757d66d0>,
#   <matplotlib.axis.YTick at 0x25c757d6be0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import matplotlib.pyplot as plt 
# create a figure and axis 
fig, ax = plt.subplots()

x = [2,4,6,6,9,2,7,2,6,1,8,4,5,9,1,2,3,7]
y = [7,8,2,4,6,4,9,5,9,3,6,7,2,4,6,7,1,9]
ax.plot(x,y)

# %%
import pandas as pd 
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','dc','california'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
    
})
#from pandas to plot multiple plots on the same line 
#'gca' stands for 'get current axis'
ax = plt.gca()

df.plot(kind='line',x='name',y='num_children',ax=ax)
df.plot(kind='line',x='name',y='num_pets',color='red',ax=ax)
# Out:
# <AxesSubplot:xlabel='name'>

# %%
import pandas as pd
iris = pd.read_csv('D:/Msc/FDS/Data/Iris.csv')
print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# get columns to plot 
columns = iris.columns.drop(['Species'])
# create x data 
x_data = range(0, iris.shape[0])
# create figure and axis 
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, iris[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
# create a figure and axis 
fig, ax = plt.subplots()
# plot histogram
ax.hist(iris['SepalLengthCm'])
# set title and labels 
ax.set_title('iris')
ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
wine_reviews = pd.read_csv("D:/Msc/FDS/Data/winemag-data-130k-v2.csv")
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
fig, ax = plt.subplots()
data = wine_reviews['points'].value_counts()
points = data.index
frequency = data.values
ax.bar(points, frequency)
ax.set_title('wine_reviews') 
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
wine_reviews['points'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
wine_reviews.groupby("country").price.mean().sort_values(ascending=False)[:5].plot.bar()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
import numpy as np
import matplotlib.pyplot as plt
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
plt.bar(y_pos, performance, width=0.5, align='center', alpha=0.7, color=['r', 'r', 'g', 'g', 'b','b'])
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.xlabel('Programming Languages')
plt.title('Programming languages usage')
# Out:
# Text(0.5, 1.0, 'Programming languages usage')

# %%
# to print the values above the bar
import matplotlib.pyplot as plt

# Declaring the figure or the plot (y,x) or (width, height)
plt.figure(figsize=(12, 7))

# Categorical data: Country names
countries = ['USA', 'Brazil', 'Russia', 'Spain', 'UK', 'India']

# integer value interms of death counts
totalDeaths = [112596, 37312, 5971, 27136, 40597, 7449]

# Passing the parameters to the bar function, this is the main function which creates the bar plot
plt.bar(countries, totalDeaths, width=0.9, align='center', color='cyan', edgecolor = 'red')

# This is the location for the annotated text
i =1.0
j =2000

# Annotating the bar plot with the values (total death counts)
for i in range(len(countries)):
    plt.annotate(totalDeaths[i], (-0.1+ i, totalDeaths[i] + j))

# Creating legend of the bars in the plot
plt.legend(labels = ['Total Deaths'])

# Giving the title for the plot
plt.title('Bar plot representing the total deaths by top 6 countries due to coronavirus')

# Naming the x and y axis
plt.xlabel('Countries')
plt.ylabel('Deaths')

# Saving the plot as a 'png'
plt.savefig("BarPlot.png")

# Display the bar plot
plt.show()# to print the values above the bar
import matplotlib.pyplot as plt

# Declaring the figure or the plot (y,x) or (width, height)
plt.figure(figsize=(12, 7))

# Categorical data: Country names
countries = ['USA', 'Brazil', 'Russia', 'Spain', 'UK', 'India']

# integer value interms of death counts
totalDeaths = [112596, 37312, 5971, 27136, 40597, 7449]

# Passing the parameters to the bar function, this is the main function which creates the bar plot
plt.bar(countries, totalDeaths, width=0.9, align='center', color='cyan', edgecolor = 'red')

# This is the location for the annotated text
i =1.0
j =2000

# Annotating the bar plot with the values (total death counts)
for i in range(len(countries)):
    plt.annotate(totalDeaths[i], (-0.1+ i, totalDeaths[i] + j))

# Creating legend of the bars in the plot
plt.legend(labels = ['Total Deaths'])

# Giving the title for the plot
plt.title('Bar plot representing the total deaths by top 6 countries due to coronavirus')

# Naming the x and y axis
plt.xlabel('Countries')
plt.ylabel('Deaths')

# Saving the plot as a 'png'
plt.savefig("BarPlot.png")

# Display the bar plot
plt.show()

# %%
wine_reviews['points'].value_counts().sort_index().plot.barh()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt 
# declaring the figure or the plot (x,y) or (width, height)
plt.figure(figsize=[14,10])

# passing parameters to the bar function, this is the main function which creates the bar plot 
# For crearting the horizontal make sure that you opened  'h' to the bar function name 
plt.barh(['USA','Brazil','Russia','Spain','UK'],[2026493,710887,476658,288797,287399], label = "Danger zone", color = 'r')
plt.barh(['India','Italy','Peru','Germany','Iran'],[265928,235278,199696,186205,173832], label = "Not safe zone", color ='g')

#creating the legend of the bars in the plot 
plt.legend()

#Naming the x and y axis 
plt.xlabel('total cases')
plt.ylabel('Countries')

#Giving the title for the plot 
plt.title('Top ten most affected countries by\n coronavirus ')

#saving the plot as png 
plt.savefig('2BarPlot.png')

# Displaying the Bar plot 
plt.show()

# %%
import pandas as pd 
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,28],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','ca;ifornia','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
    
})
#From pandas to plot multiple plots on some figure 
df.groupby(['state','gender']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='state'>

# %%
df.groupby(['gender','state']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
import pandas as pd 
from matplotlib import pyplot as plt

Data = {'Country':['USA','Canada','Germany','UK','France'],
       'GDP_Per_Capita':[45000,42000,52000,49000,47000],
       'Income_Per_Capita':[4000,5000,7000,55000,60000]
       }

df = pd.DataFrame(Data)
#Multiple metrics in some chart 
df.plot(x = 'Country', y=['GDP_Per_Capita','Income_Per_Capita'], kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
# Importing the matplot library 
import numpy as np
import matplotlib.pyplot as plt 

#Declaring the figure or the plot (x,y) or (width,height)
plt.figure(figsize=[15,10])

#Data to be plotted
totalDeath=[113065,37312,5971,7473,33964]
totalRecovery=[773480,325602,230688,129095,166584]
activeCases=[1139958,347973,239999,129360,34730]
country=['USA','Brazil','Russia','India','Italy']

# using numpy to group 3 different data with bars 
X = np.arange(len(totalDeath))

plt.bar(X, totalDeath,color = 'black',width = 0.25)
plt.bar(X + 0.25, totalRecovery, color='g', width=0.25)
plt.bar(X + 0.25, activeCases, color='b',width=0.25)

#Creating the legend of the bars in the plot 
plt.legend(['Total Deaths','Total Recovery','Active Cases'])

# Overiding the legend of the bars in the plot 
plt.xticks([i + 0.25 for i in range(5)], country)

#Giving the title for thw plot 
plt.title("Bar plot representing the total deaths, total recovered cases and active cases")

# Naming x and y axis 
plt.xlabel('Countries')
plt.ylabel('Cases')

# Saving the plot as png 
plt.savefig('4BarPlot.png')

#Displaying the bar plot 
plt.show()

# %%
# Data from plotting
from pandas import DataFrame
import matplotlib.pyplot as plt

Data = {'Tasks':[300,500,700],
       'Task Type':['Task Pending','Tasks Ongoing','Tasks Completed']
       }
df = DataFrame(Data)
df.set_index('Task Type',inplace = True)

# Autopct has extra % at the end as escape , as % is interpreted as formatting string begin by default 
# Only pie chart needs labels to be data frame index
df.plot.pie(y='Tasks', figsize=(10,10),autopct='%1.1f%%', startangle=90)
# Out:
# <AxesSubplot:ylabel='Tasks'>

# %%
import matplotlib.pyplot as plt 
# if using jupyter notebook , include:
# %matplotlib inline

labels=['Civil','Electrical','Mechanical','Chemical']
sizes = [15,30,45,10]

#Explode out the 'chemical' pie piece by offseting it to a greater amount
explode = (0.1,0.1,0.1,0.4)

fig, ax = plt.subplots()
ax.pie(sizes,
       explode=explode,
       labels=labels,
       autopct='%1.1f%%',
       shadow=True,
       startangle=90)
ax.axis('equal')
ax.set_title('Engineering Disciplines')
# Out:
# Text(0.5, 1.0, 'Engineering Disciplines')

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.bar(range(1,6), np.random.randint(1,20,5))
plt.title("2,2,1")
plt.subplot(2,2,2)
plt.bar(range(1,6), np.random.randint(1,20,5))
plt.title("2,2,2")
plt.subplot(2,2,3)
#s is the size of dot
plt.scatter(range(1,6), np.random.randint(1,20,5), s=100, color="r")
plt.title("2,2,3")
plt.subplot(2,2,4)
plt.plot(range(1,6), np.random.randint(1,20,5), marker='o', color='g', linestyle='--')
plt.title("2,2,4")
# Out:
# Text(0.5, 1.0, '2,2,4')

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir('D:/Msc/FDS/Data')
cars_data=pd.read_csv('Toyota.csv',index_col=0,na_values=["??","????"])
cars_data.size
# Out:
# 14360

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data.size
# Out:
# 10960

# %%
cars_data=pd.read_csv('Toyota.csv',index_col=0)
cars_data.head()
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90       1.0          0  2000  three    1165
# 1  13750  23.0  72937   Diesel  90       1.0          0  2000      3    1165
# 2  13950  24.0  41711   Diesel  90       NaN          0  2000      3    1165
# 3  14950  26.0  48000   Diesel  90       0.0          0  2000      3    1165
# 4  13750  30.0  38500   Diesel  90       0.0          0  2000      3    1170

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars_data['Age'],y=cars_data['Price'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.regplot(x=cars_data['Age'],y=cars_data['Price'], fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.regplot(x=cars_data['Age'],y=cars_data['Price'],marker="*", fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.lmplot(x='Age',y='Price',data=cars_data, fit_reg=False, hue='FuelType',legend=True, palette="Set1")

# %%
sns.distplot(cars_data['Age'])
# Out:
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.lmplot(x='Age',y='Price',data=cars_data, fit_reg=False, hue='FuelType', legend=True, palette='Set3')

# %%
sns.distplot(cars_data['Age'],kde=False)
# Out:
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(cars_data['Age'],kde=False ,bins=5)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.countplot(x="FuelType",data=cars_data)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
sns.countplot(x="FuelType",data=cars_data, hue="Automatic")
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
pd.crosstab(index=cars_data['Automatic'],columns=cars_data['FuelType'],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73

# %%
sns.boxplot(x=cars_data['FuelType'],y=cars_data["Price"])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x=cars_data['FuelType'],y=cars_data["Price"], hue="Automatic",data=cars_data)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.15,.85)})

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.15,.85)})
sns.boxplot(cars_data['Price'],ax=ax_box)
sns.distplot(cars_data['Price'],ax=ax_hist,kde=False)
# Out:
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price'>

# %%
sns.pairplot(cars_data,kind="scatter",hue="FuelType",diag_kws={'bw':0.1})
# Out:
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Personal\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Heat Map

# %%
data=np.random.randint(1,100,size=(10,10))
print("The data to be plotted:\n")
print(data)
# Out:
# The data to be plotted:
#
# [[10 51 39 88 49 72 40 15 85 97]
#  [13 22 69 86 95 69  3 87 54 61]
#  [54 58 81 23 98 61  2 51 50 48]
#  [32 40 73 34 12  1 58 19 72 86]
#  [45 31 51 17 65 59 66 76 76 20]
#  [55  4 85 77 88 86 29 15 87 23]
#  [70 68 19 52 14 16 57 13 42 12]
#  [44 68 39 52 63 91 57 69 85 27]
#  [21 14 42 91 11 16 96 14 97 58]
#  [36 71 29 14 92 31 21 66 43 15]]

# %%
hm=sns.heatmap(data=data)
plt.show()

# %%
hm=sns.heatmap(data=data,
              vmin='30',
              vmax='70')
plt.show()

# %%
# Setting the parameter values
cmap="tab20"
center=0

# Setting the parameter values 
annot=True


# Plotting the heatmap
hm=sns.heatmap(data=data, cmap=cmap, annot=annot)

# Displaying the plotted heatmap
plt.show()
